# %%
# hide
# !python -m pip install nbdev

# %%
# default_exp core

# %% [markdown]
# # core
#
# > Test core function

# %%
#hide
from nbdev.showdoc import *

# %%
#export
def double(a):
  return a * 2

# %%
a = 2
double(a)
# Out:
# 4
